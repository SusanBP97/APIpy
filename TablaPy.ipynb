# %% [markdown]
# <a href="https://colab.research.google.com/github/SusanBP97/APIpy/blob/main/TablaPy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install tabula-py[jpype]
import tabula
import pandas as pd
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 438.5/438.5 kB 18.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 73.4 MB/s eta 0:00:00
# ...

# %%
tablas  = tabula.read_pdf("sb2.pdf",pages= "all",multiple_tables=False,)

# %%
df=tablas[0]
print(df.head(10))
# Out:
#   Edición                  Fecha                   Ganador Marcador  \
# 0       I  15 de\renero\rde 1967        Green Bay\rPackers  35 - 10
# 1      II  14 de\renero\rde 1968    Green Bay\rPackers (2)  33 - 14
# 2     III  12 de\renero\rde 1969             New York Jets   16 - 7
# 3      IV  11 de\renero\rde 1970       Kansas City\rChiefs   23 - 7
# 4       V  17 de\renero\rde 1971           Baltimore Colts  16 - 13
# 5      VI  16 de\renero\rde 1972            Dallas Cowboys   24 - 3
# 6     VII  14 de\renero\rde 1973            Miami Dolphins   14 - 7
# 7    VIII  13 de\renero\rde 1974       Miami Dolphins\r(2)   24 - 7
# 8      IX  12 de\renero\rde 1975      Pittsburgh\rSteelers   16 - 6
# 9       X  18 de\renero\rde 1976  Pittsburgh\rSteelers (2)  21 - 17
#
#                  Perdedor                             Estadio  \
# 0     Kansas City\rChiefs      Los Angeles Memorial\rColiseum
# 1         Oakland Raiders                   Miami Orange Bowl
# ...

# %%
df
# Out:
#    Edición                Fecha                   Ganador    Marcador  \
# 0        I    15 deenerode 1967        Green Bay\rPackers     35 - 10
# 1       II    14 deenerode 1968    Green Bay\rPackers (2)     33 - 14
# 2      III    12 deenerode 1969             New York Jets      16 - 7
# 3       IV    11 deenerode 1970       Kansas City\rChiefs      23 - 7
# 4        V    17 deenerode 1971           Baltimore Colts     16 - 13
# ..     ...                  ...                       ...         ...
# 57   LVIII  11 defebrerode 2024   Kansas City\rChiefs (4)  25 - 22[2]
# 58     LIX   9 defebrerode 2025  Philadelphia\rEagles (2)     40 - 22
# 59      LX   8 defebrerode 2026                       NaN         NaN
# 60     LXI  14 defebrerode 2027                       NaN         NaN
# 61    LXII  13 defebrerode 2028                       NaN         NaN
#
#                     Perdedor                       Estadio  \
# 0        Kansas City\rChiefs  Los Angeles MemorialColiseum
# ...

# %%
df['Fecha']=df['Fecha'].str.replace('\r','')
df['Ciudad'] =df['Ciudad'].str.replace('\r','').str.rsplit('(0123456789)')
df['Estadio']=df['Estadio'].str.replace('\r','')

# %%
df
# Out:
#    Edición                Fecha                   Ganador    Marcador  \
# 0        I    15 deenerode 1967        Green Bay\rPackers     35 - 10
# 1       II    14 deenerode 1968    Green Bay\rPackers (2)     33 - 14
# 2      III    12 deenerode 1969             New York Jets      16 - 7
# 3       IV    11 deenerode 1970       Kansas City\rChiefs      23 - 7
# 4        V    17 deenerode 1971           Baltimore Colts     16 - 13
# ..     ...                  ...                       ...         ...
# 57   LVIII  11 defebrerode 2024   Kansas City\rChiefs (4)  25 - 22[2]
# 58     LIX   9 defebrerode 2025  Philadelphia\rEagles (2)     40 - 22
# 59      LX   8 defebrerode 2026                       NaN         NaN
# 60     LXI  14 defebrerode 2027                       NaN         NaN
# 61    LXII  13 defebrerode 2028                       NaN         NaN
#
#                     Perdedor                       Estadio  \
# 0        Kansas City\rChiefs  Los Angeles MemorialColiseum
# ...
