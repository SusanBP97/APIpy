# %% [markdown]
# <a href="https://colab.research.google.com/github/SusanBP97/APIpy/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pypdf
# !pip install PyMuPDF
# !pip install pdfminer.six
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 46.5 MB/s eta 0:00:00
# ...

# %%
from  pypdf import PdfReader
import pymupdf
from pdfminer.high_level import extract_pages,extract_text

# %%
reader = PdfReader("sample.pdf")

# %%
page = reader.pages[0]

# %%
print(page.extract_text())
# Out:
# Sample PDFThis is a simple PDF ﬁle. Fun fun fun.
# Lorem ipsum dolor sit amet, consectetuer adipiscing elit. Phasellus facilisis odio sed mi.
# Curabitur suscipit. Nullam vel nisi. Etiam semper ipsum ut lectus. Proin aliquam, erat eget
# pharetra commodo, eros mi condimentum quam, sed commodo justo quam ut velit.
# Integer a erat. Cras laoreet ligula cursus enim. Aenean scelerisque velit et tellus.
# Vestibulum dictum aliquet sem. Nulla facilisi. Vestibulum accumsan ante vitae elit. Nulla
# erat dolor, blandit in, rutrum quis, semper pulvinar, enim. Nullam varius congue risus.
# Vivamus sollicitudin, metus ut interdum eleifend, nisi tellus pellentesque elit, tristique
# accumsan eros quam et risus. Suspendisse libero odio, mattis sit amet, aliquet eget,
# hendrerit vel, nulla. Sed vitae augue. Aliquam erat volutpat. Aliquam feugiat vulputate nisl.
# Suspendisse quis nulla pretium ante pretium mollis. Proin velit ligula, sagittis at, egestas a,
# pulvinar quis, nisl.
# ...

# %%
reader1=PdfReader("A1.pdf")
# Out:
# WARNING:pypdf._reader:Ignoring wrong pointing object 12 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 46 0 (offset 0)

# %%
pages1 = reader1.pages[0]

# %%
print(pages1.extract_text())
# Out:
# Ficha técnica
# A1 Sportback 2024
#         Motorización A1 SB 35 TFSI Ego A1 SB 40 TFSI  S line
# Cilindrada 1.5 L (1,498 cm3)2.0 L  (1,984 cm3)
# Motor 4 cil. en línea, TFSI4 cil. en línea, TFSI
# Potencia 150 hp / 5,000- 6,000 rpm200 hp / 4,400-6,000 rpm
# Torque 250 Nm / 1,500 -3,500 rpm320 Nm/1,500 - 4,400 rpm
# Tracción delantera delantera
# Transmisión S tronic 7 Vel.S tronic 6 Vel.
# Velocidad máxima 222 km/ hr 235km/hr
# Aceleración 0-100 km/hr 7.7 s 6.5 s
# Rendimiento de combustible (ciudad / carretera / combinado)14.8/ 20.6/ 16.9  km/l13.7/ 19.4/ 15.8  km/l
# Norma de emisión de gases EU6 EU6
# Emisiones de CO₂ (ciudad / carretera / combinado) 159.1/ 114.0/ 138.8 gCO₂/km171.2/ 121.2/ 148.7 gCO₂/km
#        DimensionesLargo 4029 mm 4029 mm
# Ancho 1740 mm 1740 mm
# Alto 1433 mm 1433 mm
# Distancia entre ejes 2563 mm 2563 mm
# Peso en vacío (con conductor) 1,240 kg 1,335 kg
# Capacidad del maletero 335 l 335 l
# Capacidad del tanque de combustible 40 l 40 l
# ...

# %%
doc=pymupdf.open("ficha_A_A1.pdf")

# %%
page=doc.load_page(0)

# %%
print(page.get_text())
# Out:
# Ficha técnica
# A1 Sportback 2024
#         Motorización
# A1 SB 35 TFSI
# Ego
# A1 SB 40 TFSI
# S line
# Cilindrada
# 1.5 L (1,498 cm3)
# 2.0 L  (1,984 cm3)
# Motor
# 4 cil. en línea, TFSI
# 4 cil. en línea, TFSI
# Potencia
# 150 hp / 5,000- 6,000 rpm
# 200 hp / 4,400-6,000 rpm
# Torque
# 250 Nm / 1,500 -3,500 rpm
# 320 Nm/1,500 - 4,400 rpm
# Tracción
# delantera
# delantera
# Transmisión
# S tronic 7 Vel.
# S tronic 6 Vel.
# Velocidad máxima
# 222 km/ hr
# 235km/hr
# Aceleración 0-100 km/hr
# 7.7 s
# 6.5 s
# Rendimiento de combustible (ciudad / carretera / combinado)
# 14.8/ 20.6/ 16.9  km/l
# 13.7/ 19.4/ 15.8  km/l
# Norma de emisión de gases
# EU6
# EU6
# Emisiones de CO₂ (ciudad / carretera / combinado)
# 159.1/ 114.0/ 138.8 gCO₂/km
# 171.2/ 121.2/ 148.7 gCO₂/km
#        Dimensiones
# Largo
# 4029 mm
# 4029 mm
# Ancho
# 1740 mm
# 1740 mm
# Alto
# 1433 mm
# 1433 mm
# Distancia entre ejes
# 2563 mm
# 2563 mm
# Peso en vacío (con conductor)
# 1,240 kg
# 1,335 kg
# ...

# %%
text = extract_text("ficha_A_A1.pdf")

# %%
print(text)
# Out:
# A1
#
# Ficha técnica
#
# A1 Sportback 2024
#
#         Motorización
#
# A1 SB 30 TFSI
# Cool
#
# A1 SB 35 TFSI
# Ego
#
# A1 SB 40 TFSI
# S line
#
# Cilindrada
#
# Motor
#
# Potencia
#
# Torque
#
# Tracción
#
# Transmisión
#
# Velocidad máxima
#
# Aceleración 0-100 km/hr
#
# 1.0 L  (999 cm3)
#
# 1.5 L (1,498 cm3)
#
# 2.0 L  (1,984 cm3)
#
#  3 cil. en línea, TFSI
#
# 4 cil. en línea, TFSI
#
# 4 cil. en línea, TFSI
#
# 116 hp / 5,000 -5,500 rpm
#
# 150 hp / 5,000- 6,000 rpm
#
# 200 hp / 4,400-6,000 rpm
#
# 200 Nm / 2,000 - 3,500 rpm
#
# 250 Nm / 1,500 -3,500 rpm
#
# 320 Nm/1,500 - 4,400 rpm
#
# delantera
#
# S tronic 7 Vel.
#
# 203 km/hr
#
# 9.4 s
#
# delantera
#
# S tronic 7 Vel.
#
# 222 km/ hr
#
# 7.7 s
#
# delantera
#
# S tronic 6 Vel.
#
# 235km/hr
#
# 6.5 s
#
# Rendimiento de combustible (ciudad / carretera / combinado)
#
# 15.7/ 22.3/ 18.1 km/l
#
# 14.8/ 20.6/ 16.9  km/l
#
# 13.7/ 19.4/ 15.8  km/l
#
# Norma de emisión de gases
#
# EU6
#
# EU6
#
# EU6
#
# ...
